# %%
import networkx as nx
# %matplotlib inline

# %%
M=nx.read_gml("polblogs.gml.txt")

# %%
# create weighted graph from M
G = nx.Graph()
for u,v,data in M.edges_iter(data=True):
    if G.has_edge(u,v):
        G[u][v]['weight'] += 1
    else:
        G.add_edge(u, v, weight=1)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(40,40))
pos=nx.spring_layout(G, iterations=500, scale=5, k=.3)
nx.draw_networkx_labels(G, pos, fontsize=8)
font = {'fontname' : 'Helvetica',
       'color': 'k',
       'fontweight': 'bold',
       'fontsize': 14}
plt.title('Graph Centrality HW', font)

nx.draw_networkx_nodes(G,pos,node_color='b',alpha=0.4)
nx.draw_networkx_edges(G,pos,alpha=0.4,node_size=0,width=1,edge_color='k')
plt.axis('off')
plt.show()
# Out:
# C:\Anaconda2\lib\site-packages\matplotlib\font_manager.py:1288: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# <h3> What are the 10 most influential blogs? </h3>

# %% [markdown]
# 1. justmark.com
# 2. ilovecynics.com
# 3. revone.net/jarhead
# 4. nationalnewsregister.com/modules/wordpress
# 5. warriorscreed.000k3.com
# 6. andrightlyso.blogspot.com
# 7. neonbrainiac.nu/mt/blog
# 8. vernsblog.thegillfamily.us:8180
# 9. duckdaotsu.blogspot.com
# 10. myleftbrain.com

# %% [markdown]
# <h3> What are the 10 least influential blogs? </h3>

# %% [markdown]
# 1. digital-democrat.blogspot.com
# 2. thelonedem.com
# 3. americanworldview.tripod.com/weltansblog
# 4. loveamericahatebush.com
# 5. massachusetts-liberal.com
# 6. quimundus.modblog.com
# 7. democratvoice.org
# 8. thingsasitis.net
# 9. amliberal.com/blog
# 10. mcwil.blogspot.com
